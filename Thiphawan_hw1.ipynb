# %% [markdown]
# <a href="https://colab.research.google.com/github/thiphawanswu/DS532-HW1/blob/master/Thiphawan_hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests  
page = requests.get("https://www.airvisual.com/th/thailand/bangkok/sathon")
print(page)
# Out:
# <Response [200]>

# %%
print(page.content)
# Out:
# b'<!DOCTYPE html><html lang="th"><head>\n    <meta charset="utf-8">\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=5.0">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <title>Sathon \xe0\xb8\x94\xe0\xb8\xb1\xe0\xb8\x8a\xe0\xb8\x99\xe0\xb8\xb5\xe0\xb8\x84\xe0\xb8\xb8\xe0\xb8\x93\xe0\xb8\xa0\xe0\xb8\xb2\xe0\xb8\x9e\xe0\xb8\xad\xe0\xb8\xb2\xe0\xb8\x81\xe0\xb8\xb2\xe0\xb8\xa8 (AQI) \xe0\xb9\x81\xe0\xb8\xa5\xe0\xb8\xb0 Thailand \xe0\xb8\xa1\xe0\xb8\xa5\xe0\xb8\x9e\xe0\xb8\xb4\xe0\xb8\xa9\xe0\xb8\x97\xe0\xb8\xb2\xe0\xb8\x87\xe0\xb8\xad\xe0\xb8\xb2\xe0\xb8\x81\xe0\xb8\xb2\xe0\xb8\xa8 | AirVisual</title>\n    <base href="/th">    <meta name="apple-itunes-app" content="app-id=1048912974">\n    <link rel="apple-touch-icon" sizes="180x180" href="assets/favicons/apple-touch-icon.png">\n    <link rel="icon" type="image/png" sizes="32x32" href="assets/favicons/favicon-32x32.png">\n    <link rel="icon" type="image/png" sizes="16x16" href="ass
# ...

# %%
from bs4 import BeautifulSoup
page = requests.get("https://www.airvisual.com/th/thailand/bangkok/sathon") 
soup = BeautifulSoup(page.content, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="th"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=5.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Sathon ดัชนีคุณภาพอากาศ (AQI) และ Thailand มลพิษทางอากาศ | AirVisual</title>
# <base href="/th"/> <meta content="app-id=1048912974" name="apple-itunes-app"/>
# <link href="assets/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="assets/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="assets/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="assets/favicons/site.webmanifest" rel="manifest"/>
# <link color="#d9272e" href="assets/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="assets/favicons/favicon.ico?v=2" rel="shortcut icon"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# ...

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'HTML_FORMATTERS',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_attr_value_as_string',
#  '_attribute_checker',
#  '_check_markup_is_url',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
# ...

# %%
air_mywork = soup.find_all('h1')
print(type(air_mywork))
print(len(air_mywork))
# Out:
# <class 'bs4.element.ResultSet'>
# 2

# %%
air_mywork = soup.find_all('h1')
air_mywork
# Out:
# [<h1 _ngcontent-sc23="" title="&lt;b&gt;Sathon&lt;/b&gt; air quality index (AQI) and PM2.5 air pollution is 157, มีผลกระทบต่อทุกคน"><b>Sathon</b> air quality index (AQI) and PM2.5 air pollution is 157, มีผลกระทบต่อทุกคน</h1>,
#  <h1 _ngcontent-sc35="" class="page-title ng-star-inserted">Community Contributors</h1>]

# %% [markdown]
# myworkplace-Wattana

# %%
myworkplace = air_mywork[0].text
myworkplace
# Out:
# 'Sathon air quality index (AQI) and PM2.5 air pollution is 157, มีผลกระทบต่อทุกคน'

# %%
page = requests.get("https://www.airvisual.com/th/thailand/nakhon-ratchasima") 
soup2 = BeautifulSoup(page.content, 'html.parser')

print(soup2)
# Out:
# <!DOCTYPE html>
# <html lang="th"><head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=5.0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Nakhon Ratchasima ดัชนีคุณภาพอากาศ (AQI) และ Thailand มลพิษทางอากาศ | AirVisual</title>
# <base href="/th"/> <meta content="app-id=1048912974" name="apple-itunes-app"/>
# <link href="assets/favicons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="assets/favicons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="assets/favicons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="assets/favicons/site.webmanifest" rel="manifest"/>
# <link color="#d9272e" href="assets/favicons/safari-pinned-tab.svg" rel="mask-icon"/>
# <link href="assets/favicons/favicon.ico?v=2" rel="shortcut icon"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# ...

# %%
air_myhome = soup2.find_all('h1')
air_myhome
# Out:
# [<h1 _ngcontent-sc22="" title="&lt;b&gt;Nakhon Ratchasima&lt;/b&gt; air quality index (AQI) and PM2.5 air pollution is 160, มีผลกระทบต่อทุกคน"><b>Nakhon Ratchasima</b> air quality index (AQI) and PM2.5 air pollution is 160, มีผลกระทบต่อทุกคน</h1>]

# %% [markdown]
# Myhome - Samutprakan

# %%
myhome = air_myhome[0].text
myhome
# Out:
# 'Nakhon Ratchasima air quality index (AQI) and PM2.5 air pollution is 160, มีผลกระทบต่อทุกคน'
